# %%
import pandas as pd

# %%
df1 = pd.read_csv("venv/employee_data.csv")

# %%
# read all the rows and columns
# sql : select * from employee_data
df1 = pd.read_csv("venv/employee_data.csv")

# %%
df1
# Out:
#    EmpID  EmpName Department              JobTitle  Salary  Gender    HireDate
# 0    101    Alice         HR               Manager   75000  Female  2018-03-15
# 1    102      Bob         IT     Software Engineer   85000    Male  2019-07-22
# 2    103  Charlie    Finance               Analyst   65000    Male  2020-01-10
# 3    104    Diana         IT        Data Scientist   95000  Female  2021-06-25
# 4    105   Edward      Sales       Sales Executive   55000    Male  2017-09-05
# 5    106    Fiona  Marketing        SEO Specialist   60000  Female  2020-10-14
# 6    107   George         HR             Recruiter   58000    Male  2021-02-01
# 7    108    Helen    Finance            Accountant   70000  Female  2018-11-11
# 8    109      Ian         IT  System Administrator   78000    Male  2019-12-02
# 9    110     Jane      Sales         Sales Manager   88000  Female  2016-05-20

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# read empid & salary from the table.
# sql : select empid,salary from employee_data
df2 = pd.read_csv("venv/employee_data.csv",usecols=['EmpID','Salary'])

# %%
df2
# Out:
#    EmpID  Salary
# 0    101   75000
# 1    102   85000
# 2    103   65000
# 3    104   95000
# 4    105   55000
# 5    106   60000
# 6    107   58000
# 7    108   70000
# 8    109   78000
# 9    110   88000

# %%
df2['EmpID']
# Out:
# 0    101
# 1    102
# 2    103
# 3    104
# 4    105
# 5    106
# 6    107
# 7    108
# 8    109
# 9    110
# Name: EmpID, dtype: int64

# %%
df1[['EmpID','EmpName','Salary']]
# Out:
#    EmpID  EmpName  Salary
# 0    101    Alice   75000
# 1    102      Bob   85000
# 2    103  Charlie   65000
# 3    104    Diana   95000
# 4    105   Edward   55000
# 5    106    Fiona   60000
# 6    107   George   58000
# 7    108    Helen   70000
# 8    109      Ian   78000
# 9    110     Jane   88000

# %%
df_eno_ename_esal =df1[['EmpID','EmpName','Salary']]

# %%
type(df_eno_ename_esal)
# Out:
# pandas.core.frame.DataFrame

# %%
df_eno_ename_esal.dtypes
# Out:
# EmpID       int64
# EmpName    object
# Salary      int64
# dtype: object

# %%
df_eno_ename_esal
# Out:
#    EmpID  EmpName  Salary
# 0    101    Alice   75000
# 1    102      Bob   85000
# 2    103  Charlie   65000
# 3    104    Diana   95000
# 4    105   Edward   55000
# 5    106    Fiona   60000
# 6    107   George   58000
# 7    108    Helen   70000
# 8    109      Ian   78000
# 9    110     Jane   88000

# %%
# 2.Handling Delimiters(file is separated by semi colon ;)
df = pd.read_csv("venv/employee_data.csv", delimiter=';')

# %%
# Read the file with appropriate data types
df = pd.read_csv("venv/employee_data.csv",parse_dates=['HireDate'])
# data types of each columns
df.dtypes
# Out:
# EmpID                  int64
# EmpName               object
# Department            object
# JobTitle              object
# Salary                 int64
# Gender                object
# HireDate      datetime64[ns]
# dtype: object

# %%
# display the date field
df['HireDate']
# Out:
# 0   2018-03-15
# 1   2019-07-22
# 2   2020-01-10
# 3   2021-06-25
# 4   2017-09-05
# 5   2020-10-14
# 6   2021-02-01
# 7   2018-11-11
# 8   2019-12-02
# 9   2016-05-20
# Name: HireDate, dtype: datetime64[ns]

# %%
# extract the year from date
df['HireDate'].dt.year
# Out:
# 0    2018
# 1    2019
# 2    2020
# 3    2021
# 4    2017
# 5    2020
# 6    2021
# 7    2018
# 8    2019
# 9    2016
# Name: HireDate, dtype: int32

# %%
# extrac the month from date
df['HireDate'].dt.month
# Out:
# 0     3
# 1     7
# 2     1
# 3     6
# 4     9
# 5    10
# 6     2
# 7    11
# 8    12
# 9     5
# Name: HireDate, dtype: int32

# %%
# extrac the day from date
df['HireDate'].dt.day
# Out:
# 0    15
# 1    22
# 2    10
# 3    25
# 4     5
# 5    14
# 6     1
# 7    11
# 8     2
# 9    20
# Name: HireDate, dtype: int32

# %%
# extrac the weekday from date
df['HireDate'].dt.weekday
# Out:
# 0    3
# 1    0
# 2    4
# 3    4
# 4    1
# 5    2
# 6    0
# 7    6
# 8    0
# 9    4
# Name: HireDate, dtype: int32

# %%
df.dtypes
# Out:
# EmpID                  int64
# EmpName               object
# Department            object
# JobTitle              object
# Salary                 int64
# Gender                object
# HireDate      datetime64[ns]
# dtype: object

# %%
# Can we convert the datatype while reading the data from file ( e.g. ) salary field to be convereted from float to int
df = pd.read_csv("venv/employee_data.csv",parse_dates=['HireDate'],dtype={"EmpID":float})

# %%
df.dtypes
# Out:
# EmpID                  int64
# EmpName               object
# Department            object
# JobTitle              object
# Salary                 int64
# Gender                object
# HireDate      datetime64[ns]
# dtype: object

# %%
df
# Out:
#    EmpID  EmpName Department              JobTitle  Salary  Gender   HireDate
# 0  101.0    Alice         HR               Manager   75000  Female 2018-03-15
# 1  102.0      Bob         IT     Software Engineer   85000    Male 2019-07-22
# 2  103.0  Charlie    Finance               Analyst   65000    Male 2020-01-10
# 3  104.0    Diana         IT        Data Scientist   95000  Female 2021-06-25
# 4  105.0   Edward      Sales       Sales Executive   55000    Male 2017-09-05
# 5  106.0    Fiona  Marketing        SEO Specialist   60000  Female 2020-10-14
# 6  107.0   George         HR             Recruiter   58000    Male 2021-02-01
# 7  108.0    Helen    Finance            Accountant   70000  Female 2018-11-11
# 8  109.0      Ian         IT  System Administrator   78000    Male 2019-12-02
# 9  110.0     Jane      Sales         Sales Manager   88000  Female 2016-05-20

# %%
# Read sepcific row ( index number = 1)
df.iloc[1]
# Out:
# EmpID                       102.0
# EmpName                       Bob
# Department                     IT
# JobTitle        Software Engineer
# Salary                      85000
# Gender                       Male
# HireDate      2019-07-22 00:00:00
# Name: 1, dtype: object

# %%
# Read specific rows ( index no. 1 to 5) 
df.iloc[5:10:1]
# Out:
#    EmpID EmpName Department              JobTitle  Salary  Gender   HireDate
# 5  106.0   Fiona  Marketing        SEO Specialist   60000  Female 2020-10-14
# 6  107.0  George         HR             Recruiter   58000    Male 2021-02-01
# 7  108.0   Helen    Finance            Accountant   70000  Female 2018-11-11
# 8  109.0     Ian         IT  System Administrator   78000    Male 2019-12-02
# 9  110.0    Jane      Sales         Sales Manager   88000  Female 2016-05-20

# %%
# How can we read only row number 5 to 10 from the file.
df = pd.read_csv("venv/employee_data.csv",skiprows=5,nrows=5,header=None,names=["EID","EName","Dept","JobTitle","Sal","Gen","Doj"])

# %%
df
# Out:
#    105  Edward      Sales       Sales Executive  55000    Male  2017-09-05
# 0  106   Fiona  Marketing        SEO Specialist  60000  Female  2020-10-14
# 1  107  George         HR             Recruiter  58000    Male  2021-02-01
# 2  108   Helen    Finance            Accountant  70000  Female  2018-11-11
# 3  109     Ian         IT  System Administrator  78000    Male  2019-12-02
# 4  110    Jane      Sales         Sales Manager  88000  Female  2016-05-20

# %%
df = pd.read_csv("venv/employee_data.csv",header=5)

# %%
df
# Out:
#    105  Edward      Sales       Sales Executive  55000    Male  2017-09-05
# 0  106   Fiona  Marketing        SEO Specialist  60000  Female  2020-10-14
# 1  107  George         HR             Recruiter  58000    Male  2021-02-01
# 2  108   Helen    Finance            Accountant  70000  Female  2018-11-11
# 3  109     Ian         IT  System Administrator  78000    Male  2019-12-02
# 4  110    Jane      Sales         Sales Manager  88000  Female  2016-05-20

# %%
# Read a csv file with semi colon as seperator ( delimiter )
df = pd.read_csv(venv/"employee_data.csv",delimiter=";")

# %%
df
# Out:
#    105  Edward      Sales       Sales Executive  55000    Male  2017-09-05
# 0  106   Fiona  Marketing        SEO Specialist  60000  Female  2020-10-14
# 1  107  George         HR             Recruiter  58000    Male  2021-02-01
# 2  108   Helen    Finance            Accountant  70000  Female  2018-11-11
# 3  109     Ian         IT  System Administrator  78000    Male  2019-12-02
# 4  110    Jane      Sales         Sales Manager  88000  Female  2016-05-20

# %%
# Read a csv file with semi colon as seperator ( delimiter )
df = pd.read_csv(venv/"employee_data.csv",delimiter=",")

# %%
df
# Out:
#    105  Edward      Sales       Sales Executive  55000    Male  2017-09-05
# 0  106   Fiona  Marketing        SEO Specialist  60000  Female  2020-10-14
# 1  107  George         HR             Recruiter  58000    Male  2021-02-01
# 2  108   Helen    Finance            Accountant  70000  Female  2018-11-11
# 3  109     Ian         IT  System Administrator  78000    Male  2019-12-02
# 4  110    Jane      Sales         Sales Manager  88000  Female  2016-05-20

# %%
# Read the zipped file
df = pd.read_csv("venv/employee_data.csv.gz",compression='gzip')

# %%
df
# Out:
#    105  Edward      Sales       Sales Executive  55000    Male  2017-09-05
# 0  106   Fiona  Marketing        SEO Specialist  60000  Female  2020-10-14
# 1  107  George         HR             Recruiter  58000    Male  2021-02-01
# 2  108   Helen    Finance            Accountant  70000  Female  2018-11-11
# 3  109     Ian         IT  System Administrator  78000    Male  2019-12-02
# 4  110    Jane      Sales         Sales Manager  88000  Female  2016-05-20

# %%
# peformance optimization ( chunksize)
df =pd.read_csv("venv/employee_data.csv.gz")

# %%
df
# Out:
#    105  Edward      Sales       Sales Executive  55000    Male  2017-09-05
# 0  106   Fiona  Marketing        SEO Specialist  60000  Female  2020-10-14
# 1  107  George         HR             Recruiter  58000    Male  2021-02-01
# 2  108   Helen    Finance            Accountant  70000  Female  2018-11-11
# 3  109     Ian         IT  System Administrator  78000    Male  2019-12-02
# 4  110    Jane      Sales         Sales Manager  88000  Female  2016-05-20

# %%
for cnk in pd.read_csv("venv/employee_data.csv",chunksize=5):
    print(cnk)
# Out:
#    EmpID  EmpName Department           JobTitle  Salary  Gender    HireDate
# 0    101    Alice         HR            Manager   75000  Female  15-03-2018
# 1    102      Bob         IT  Software Engineer   85000    Male  22-07-2019
# 2    103  Charlie    Finance            Analyst   65000    Male  10-01-2020
# 3    104    Diana         IT     Data Scientist   95000  Female  25-06-2021
# 4    105   Edward      Sales    Sales Executive   55000    Male  05-09-2017
#    EmpID EmpName Department              JobTitle  Salary  Gender    HireDate
# 5    106   Fiona  Marketing        SEO Specialist   60000  Female  14-10-2020
# 6    107  George         HR             Recruiter   58000    Male  01-02-2021
# 7    108   Helen    Finance            Accountant   70000  Female  11-11-2018
# 8    109     Ian         IT  System Administrator   78000    Male  02-12-2019
# 9    110    Jane      Sales         Sales Manager   88000  Female  20-05-2016

# %%
# Low memory = True ( default ) this is file reading during chunk might be data corruption this is performance point of view
df = pd.read_csv("venv/employee_data.csv",low_memory=True)

# To avoid any data corruption, we should set low_memory flag as False

# %%
df.head(10)
# Out:
#    105  Edward      Sales       Sales Executive  55000    Male  2017-09-05
# 0  106   Fiona  Marketing        SEO Specialist  60000  Female  2020-10-14
# 1  107  George         HR             Recruiter  58000    Male  2021-02-01
# 2  108   Helen    Finance            Accountant  70000  Female  2018-11-11
# 3  109     Ian         IT  System Administrator  78000    Male  2019-12-02
# 4  110    Jane      Sales         Sales Manager  88000  Female  2016-05-20

# %%
df.tail(4)
# Out:
#    105  Edward    Sales       Sales Executive  55000    Male  2017-09-05
# 1  107  George       HR             Recruiter  58000    Male  2021-02-01
# 2  108   Helen  Finance            Accountant  70000  Female  2018-11-11
# 3  109     Ian       IT  System Administrator  78000    Male  2019-12-02
# 4  110    Jane    Sales         Sales Manager  88000  Female  2016-05-20

# %%
df = pd.read_csv("venv/employee_data.csv",parse_dates=['HireDate'])
df['HireDate'].head()
df.dtypes
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_8308\1555331484.py:1: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df = pd.read_csv("venv/employee_data.csv",parse_dates=['HireDate'])
# EmpID                  int64
# EmpName               object
# Department            object
# JobTitle              object
# Salary                 int64
# Gender                object
# HireDate      datetime64[ns]
# dtype: object

# %%
df['HireDate'] = df['HireDate'].dt.strftime('%m-%d-%y')

# %%
df.dtypes
# Out:
# EmpID                  int64
# EmpName               object
# Department            object
# JobTitle              object
# Salary                 int64
# Gender                object
# HireDate      datetime64[ns]
# dtype: object

# %%
df = pd.read_csv("venv/employee_data.csv",parse_dates=['HireDate'])
df['HireDate'].head()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_8308\4007156047.py:1: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df = pd.read_csv("venv/employee_data.csv",parse_dates=['HireDate'])
# 0   2018-03-15
# 1   2019-07-22
# 2   2020-01-10
# 3   2021-06-25
# 4   2017-09-05
# Name: HireDate, dtype: datetime64[ns]
